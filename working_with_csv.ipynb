# %%
import requests
import pandas as pd
from io import StringIO
url = 'https://raw.githubusercontent.com/amankharwal/Website-data/master/heart.csv'
response = requests.get(url)
if response.status_code == 200:
  data = StringIO(response.text)
else:
  print('Failed to Load')


df = pd.read_csv(data)
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
pd.read_csv('placement.csv', usecols=['cgpa', 'iq', 'placement'])
# Out:
#     cgpa     iq  placement
# 0    6.8  123.0          1
# 1    5.9  106.0          0
# 2    5.3  121.0          0
# 3    7.4  132.0          1
# 4    5.8  142.0          0
# ..   ...    ...        ...
# 95   4.3  200.0          0
# 96   4.4   42.0          0
# 97   6.7  182.0          1
# 98   6.3  103.0          1
# 99   6.2  113.0          1
#
# [100 rows x 3 columns]

# %%
pd.read_csv('placement.csv', usecols=['cgpa'], squeeze=True)
# Out:
# <ipython-input-13-5dc97b692720>:1: FutureWarning: The squeeze argument has been deprecated and will be removed in a future version. Append .squeeze("columns") to the call to squeeze.
#
#
#   pd.read_csv('placement.csv', usecols=['cgpa'], squeeze=True)
# 0     6.8
# 1     5.9
# 2     5.3
# 3     7.4
# 4     5.8
#      ...
# 95    4.3
# 96    4.4
# 97    6.7
# 98    6.3
# 99    6.2
# Name: cgpa, Length: 100, dtype: float64

# %%
pd.read_csv('placement.csv', skiprows=[0,4])
# Out:
#      0  6.8  123.0  1
# 0    1  5.9  106.0  0
# 1    2  5.3  121.0  0
# 2    4  5.8  142.0  0
# 3    5  7.1   48.0  1
# 4    6  5.7  143.0  0
# ..  ..  ...    ... ..
# 93  95  4.3  200.0  0
# 94  96  4.4   42.0  0
# 95  97  6.7  182.0  1
# 96  98  6.3  103.0  1
# 97  99  6.2  113.0  1
#
# [98 rows x 4 columns]

# %%
pd.read_csv('placement.csv', nrows=50)
# Out:
#     Unnamed: 0  cgpa     iq  placement
# 0            0   6.8  123.0          1
# 1            1   5.9  106.0          0
# 2            2   5.3  121.0          0
# 3            3   7.4  132.0          1
# 4            4   5.8  142.0          0
# 5            5   7.1   48.0          1
# 6            6   5.7  143.0          0
# 7            7   5.0   63.0          0
# 8            8   6.1  156.0          0
# 9            9   5.1   66.0          0
# 10          10   6.0   45.0          1
# 11          11   6.9  138.0          1
# 12          12   5.4  139.0          0
# 13          13   6.4  116.0          1
# 14          14   6.1  103.0          0
# 15          15   5.1  176.0          0
# 16          16   5.2  224.0          0
# 17          17   3.3  183.0          0
# 18          18   4.0  100.0          0
# 19          19   5.2  132.0          0
# 20          20   6.6  120.0          1
# 21          21   7.1  151.0          1
# 22          22   4.9  120.0          0
# ...

# %%
pd.read_csv('placement.csv',dtype={'iq':int})
# Out:
#     Unnamed: 0  cgpa   iq  placement
# 0            0   6.8  123          1
# 1            1   5.9  106          0
# 2            2   5.3  121          0
# 3            3   7.4  132          1
# 4            4   5.8  142          0
# ..         ...   ...  ...        ...
# 95          95   4.3  200          0
# 96          96   4.4   42          0
# 97          97   6.7  182          1
# 98          98   6.3  103          1
# 99          99   6.2  113          1
#
# [100 rows x 4 columns]

# %%
dfs=pd.read_csv('placement.csv', chunksize=20)

# %%
for chunks in dfs:
  print(chunks.shape)
# Out:
# (20, 4)
# (20, 4)
# (20, 4)
# (20, 4)
